# %% [markdown]
# # One Shot Learning with Siamese Networks
#
# This is the jupyter notebook that accompanies

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %% [markdown]
# ## Helper functions
# Set of helper functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %% [markdown]
# ## Configuration Class
# A simple class to manage configuration

# %%
class Config():
    training_dir = "./data/faces/training/"
    testing_dir = "./data/faces/testing/"
    train_batch_size = 64
    train_number_epochs = 100

# %% [markdown]
# ## Custom Dataset Class
# This dataset generates a pair of images. 0 for geniune pair and 1 for imposter pair

# %%
class SiameseNetworkDataset(Dataset):
    
    def __init__(self,imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            while True:
                #keep looping till a different class image is found
                
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] !=img1_tuple[1]:
                    break
            img1_tuple = random.choice(self.imageFolderDataset.imgs)

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %% [markdown]
# ## Using Image Folder Dataset

# %%
folder_dataset = dset.ImageFolder(root=Config.training_dir)

# %%
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image.
# 1 indiciates dissimilar, and 0 indicates similar.

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[0.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]
#  [0.]
#  [1.]
#  [1.]]

# %% [markdown]
# ## Neural Net Definition
# We will use a standard convolutional neural network

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(1, 4, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(4),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(4, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


            nn.ReflectionPad2d(1),
            nn.Conv2d(8, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),


        )

        self.fc1 = nn.Sequential(
            nn.Linear(8*100*100, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 5))

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ## Contrastive Loss

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training Time!

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())
show_plot(counter,loss_history)
# Out:
# Epoch number 0
#  Current loss 2.063828706741333
#
# Epoch number 0
#  Current loss 1.2641990184783936
#
# Epoch number 1
#  Current loss 1.2572901248931885
#
# Epoch number 1
#  Current loss 1.1712685823440552
#
# Epoch number 2
#  Current loss 1.1383519172668457
#
# Epoch number 2
#  Current loss 1.118727684020996
#
# Epoch number 3
#  Current loss 1.1450281143188477
#
# Epoch number 3
#  Current loss 1.185054898262024
#
# Epoch number 4
#  Current loss 1.1052697896957397
#
# Epoch number 4
#  Current loss 1.0907926559448242
#
# Epoch number 5
#  Current loss 1.118422031402588
#
# Epoch number 5
#  Current loss 1.193350076675415
#
# Epoch number 6
#  Current loss 1.1823045015335083
#
# Epoch number 6
#  Current loss 1.1951334476470947
#
# Epoch number 7
#  Current loss 1.0661712884902954
#
# Epoch number 7
#  Current loss 1.1774728298187256
#
# Epoch number 8
#  Current loss 1.126923680305481
#
# Epoch number 8
#  Current loss 1.094637155532837
#
# Epoch number 9
#  Current loss 1.0796235799789429
#
# Epoch number 9
#  Current loss 1.1731771230697632
#
# Epoch number 10
#  Current loss 1.1531918048858643
#
# Epoch number 10
#  Current loss 1.1906629800796509
#
# Epoch number 11
#  Current loss 1.1882963180541992
#
# Epoch number 11
#  Current loss 1.1545507907867432
#
# Epoch number 12
#  Current loss 1.1345645189285278
#
# Epoch number 12
#  Current loss 1.1386187076568604
#
# Epoch number 13
#  Current loss 1.0337200164794922
#
# Epoch number 13
#  Current loss 1.173834204673767
#
# Epoch number 14
#  Current loss 1.1422581672668457
#
# Epoch number 14
#  Current loss 1.0870023965835571
#
# Epoch number 15
#  Current loss 1.1319788694381714
#
# Epoch number 15
#  Current loss 1.1353849172592163
#
# Epoch number 16
#  Current loss 1.1101906299591064
#
# Epoch number 16
#  Current loss 1.1442874670028687
#
# Epoch number 17
#  Current loss 1.1183937788009644
#
# Epoch number 17
#  Current loss 1.0901062488555908
#
# Epoch number 18
#  Current loss 1.043350338935852
#
# Epoch number 18
#  Current loss 1.1348693370819092
#
# Epoch number 19
#  Current loss 1.2169151306152344
#
# Epoch number 19
#  Current loss 1.2035280466079712
#
# Epoch number 20
#  Current loss 1.2208853960037231
#
# Epoch number 20
#  Current loss 1.162400484085083
#
# Epoch number 21
#  Current loss 1.1792593002319336
#
# Epoch number 21
#  Current loss 1.1770873069763184
#
# Epoch number 22
#  Current loss 1.1817220449447632
#
# Epoch number 22
#  Current loss 1.127732753753662
#
# Epoch number 23
#  Current loss 1.140643835067749
#
# Epoch number 23
#  Current loss 1.1168054342269897
#
# Epoch number 24
#  Current loss 1.1956877708435059
#
# Epoch number 24
#  Current loss 1.1682441234588623
#
# Epoch number 25
#  Current loss 1.1371160745620728
#
# Epoch number 25
#  Current loss 1.2030127048492432
#
# Epoch number 26
#  Current loss 1.1187435388565063
#
# Epoch number 26
#  Current loss 1.166501760482788
#
# Epoch number 27
#  Current loss 1.1181271076202393
#
# Epoch number 27
#  Current loss 1.116682529449463
#
# Epoch number 28
#  Current loss 1.1159712076187134
#
# Epoch number 28
#  Current loss 1.1818037033081055
#
# Epoch number 29
#  Current loss 1.1202458143234253
#
# Epoch number 29
#  Current loss 1.1095315217971802
#
# Epoch number 30
#  Current loss 1.1180040836334229
#
# Epoch number 30
#  Current loss 1.1200251579284668
#
# Epoch number 31
#  Current loss 1.1661806106567383
#
# Epoch number 31
#  Current loss 1.1293675899505615
#
# Epoch number 32
#  Current loss 1.0681153535842896
#
# Epoch number 32
#  Current loss 1.1096148490905762
#
# Epoch number 33
#  Current loss 1.1197634935379028
#
# Epoch number 33
#  Current loss 1.1742491722106934
#
# Epoch number 34
#  Current loss 1.1019258499145508
#
# Epoch number 34
#  Current loss 1.1719517707824707
#
# Epoch number 35
#  Current loss 1.204236626625061
#
# Epoch number 35
#  Current loss 1.1064579486846924
#
# Epoch number 36
#  Current loss 1.2255971431732178
#
# Epoch number 36
#  Current loss 1.0738370418548584
#
# Epoch number 37
#  Current loss 1.1098055839538574
#
# Epoch number 37
#  Current loss 1.093861699104309
#
# Epoch number 38
#  Current loss 1.1356120109558105
#
# Epoch number 38
#  Current loss 1.0620405673980713
#
# Epoch number 39
#  Current loss 1.181723713874817
#
# Epoch number 39
#  Current loss 1.1070233583450317
#
# Epoch number 40
#  Current loss 1.1066749095916748
#
# Epoch number 40
#  Current loss 1.1392171382904053
#
# Epoch number 41
#  Current loss 1.1648495197296143
#
# Epoch number 41
#  Current loss 1.17120361328125
#
# Epoch number 42
#  Current loss 1.152915596961975
#
# Epoch number 42
#  Current loss 1.1272482872009277
#
# Epoch number 43
#  Current loss 1.120572566986084
#
# Epoch number 43
#  Current loss 1.1413781642913818
#
# Epoch number 44
#  Current loss 1.2303030490875244
#
# Epoch number 44
#  Current loss 1.1650052070617676
#
# Epoch number 45
#  Current loss 1.1028589010238647
#
# Epoch number 45
#  Current loss 1.1111990213394165
#
# Epoch number 46
#  Current loss 1.1255066394805908
#
# Epoch number 46
#  Current loss 1.1037132740020752
#
# Epoch number 47
#  Current loss 1.140070915222168
#
# Epoch number 47
#  Current loss 1.1445667743682861
#
# Epoch number 48
#  Current loss 1.1674561500549316
#
# Epoch number 48
#  Current loss 1.0766657590866089
#
# Epoch number 49
#  Current loss 1.2332671880722046
#
# Epoch number 49
#  Current loss 1.1442610025405884
#
# Epoch number 50
#  Current loss 1.2067737579345703
#
# Epoch number 50
#  Current loss 1.1053540706634521
#
# Epoch number 51
#  Current loss 1.1575310230255127
#
# Epoch number 51
#  Current loss 1.1005887985229492
#
# Epoch number 52
#  Current loss 1.0691674947738647
#
# Epoch number 52
#  Current loss 1.0644025802612305
#
# Epoch number 53
#  Current loss 1.2205004692077637
#
# Epoch number 53
#  Current loss 1.201327919960022
#
# Epoch number 54
#  Current loss 1.1420073509216309
#
# Epoch number 54
#  Current loss 1.1469135284423828
#
# Epoch number 55
#  Current loss 1.1373306512832642
#
# Epoch number 55
#  Current loss 1.1127398014068604
#
# Epoch number 56
#  Current loss 1.0590345859527588
#
# Epoch number 56
#  Current loss 1.0734665393829346
#
# Epoch number 57
#  Current loss 1.2207908630371094
#
# Epoch number 57
#  Current loss 1.1618154048919678
#
# Epoch number 58
#  Current loss 1.0916074514389038
#
# Epoch number 58
#  Current loss 1.0640201568603516
#
# Epoch number 59
#  Current loss 1.0758538246154785
#
# Epoch number 59
#  Current loss 1.0987577438354492
#
# Epoch number 60
#  Current loss 1.1072720289230347
#
# Epoch number 60
#  Current loss 1.0805171728134155
#
# Epoch number 61
#  Current loss 1.0322881937026978
#
# Epoch number 61
#  Current loss 1.13426673412323
#
# Epoch number 62
#  Current loss 1.1577861309051514
#
# Epoch number 62
#  Current loss 1.1240884065628052
#
# Epoch number 63
#  Current loss 1.0728840827941895
#
# Epoch number 63
#  Current loss 1.0802658796310425
#
# Epoch number 64
#  Current loss 1.1281933784484863
#
# Epoch number 64
#  Current loss 1.0632654428482056
#
# Epoch number 65
#  Current loss 1.109052062034607
#
# Epoch number 65
#  Current loss 1.0509755611419678
#
# Epoch number 66
#  Current loss 1.2256759405136108
#
# Epoch number 66
#  Current loss 1.1317983865737915
#
# Epoch number 67
#  Current loss 1.115938425064087
#
# Epoch number 67
#  Current loss 1.1230659484863281
#
# Epoch number 68
#  Current loss 1.0998740196228027
#
# Epoch number 68
#  Current loss 1.0853948593139648
#
# Epoch number 69
#  Current loss 1.1221975088119507
#
# Epoch number 69
#  Current loss 1.1219170093536377
#
# Epoch number 70
#  Current loss 1.077798843383789
#
# Epoch number 70
#  Current loss 1.0359169244766235
#
# Epoch number 71
#  Current loss 1.1061582565307617
#
# Epoch number 71
#  Current loss 1.1588001251220703
#
# Epoch number 72
#  Current loss 1.1165785789489746
#
# Epoch number 72
#  Current loss 1.1607447862625122
#
# Epoch number 73
#  Current loss 1.1058287620544434
#
# Epoch number 73
#  Current loss 1.1186878681182861
#
# Epoch number 74
#  Current loss 1.1765350103378296
#
# Epoch number 74
#  Current loss 1.0994653701782227
#
# Epoch number 75
#  Current loss 1.1335225105285645
#
# Epoch number 75
#  Current loss 1.067253828048706
#
# Epoch number 76
#  Current loss 1.2163885831832886
#
# Epoch number 76
#  Current loss 1.1209931373596191
#
# Epoch number 77
#  Current loss 1.0728665590286255
#
# Epoch number 77
#  Current loss 1.1646337509155273
#
# Epoch number 78
#  Current loss 1.1335575580596924
#
# Epoch number 78
#  Current loss 1.0932583808898926
#
# Epoch number 79
#  Current loss 1.0832126140594482
#
# Epoch number 79
#  Current loss 1.0604387521743774
#
# Epoch number 80
#  Current loss 1.0752190351486206
#
# Epoch number 80
#  Current loss 1.148028016090393
#
# Epoch number 81
#  Current loss 1.1719529628753662
#
# Epoch number 81
#  Current loss 1.0948481559753418
#
# Epoch number 82
#  Current loss 1.0889602899551392
# Epoch number 82
#  Current loss 1.0602548122406006
#
# Epoch number 83
#  Current loss 1.1782007217407227
#
# Epoch number 83
#  Current loss 1.1518590450286865
#
# Epoch number 84
#  Current loss 1.1401078701019287
#
# Epoch number 84
#  Current loss 1.2347126007080078
#
# Epoch number 85
#  Current loss 1.1367183923721313
#
# Epoch number 85
#  Current loss 1.1030733585357666
#
# Epoch number 86
#  Current loss 1.100653052330017
#
# Epoch number 86
#  Current loss 1.0889697074890137
#
# Epoch number 87
#  Current loss 1.1113321781158447
#
# Epoch number 87
#  Current loss 1.0743119716644287
#
# Epoch number 88
#  Current loss 1.1264925003051758
#
# Epoch number 88
#  Current loss 1.1574342250823975
#
# Epoch number 89
#  Current loss 1.0827538967132568
#
# Epoch number 89
#  Current loss 1.139253854751587
#
# Epoch number 90
#  Current loss 1.1331080198287964
#
# Epoch number 90
#  Current loss 1.0901209115982056
#
# Epoch number 91
#  Current loss 1.080818772315979
#
# Epoch number 91
#  Current loss 1.0774955749511719
#
# Epoch number 92
#  Current loss 1.0882989168167114
#
# Epoch number 92
#  Current loss 1.1053907871246338
#
# Epoch number 93
#  Current loss 1.0794795751571655
#
# Epoch number 93
#  Current loss 1.144888162612915
#
# Epoch number 94
#  Current loss 1.1068416833877563
#
# Epoch number 94
#  Current loss 1.2468788623809814
#
# Epoch number 95
#  Current loss 1.1357964277267456
#
# Epoch number 95
#  Current loss 1.0674290657043457
#
# Epoch number 96
#  Current loss 1.139662742614746
#
# Epoch number 96
#  Current loss 1.1615914106369019
#
# Epoch number 97
#  Current loss 1.169980764389038
#
# Epoch number 97
#  Current loss 1.084891438484192
#
# Epoch number 98
#  Current loss 1.1358895301818848
#
# Epoch number 98
#  Current loss 1.1566438674926758
#
# Epoch number 99
#  Current loss 1.1984140872955322
#
# Epoch number 99
#  Current loss 1.0962493419647217

# %% [markdown]
# ## Some simple testing
# The last 3 subjects were held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.

# %%
folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))
